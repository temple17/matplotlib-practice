# %% [markdown]
# <a href="https://colab.research.google.com/github/temple17/matplotlib-practice/blob/main/4_Horizontal_bar_chart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
import matplotlib
matplotlib.__version__
# Out:
# '3.5.2'

# %%
# !pip install matplotlib --upgrade

# %%
np.random.seed(19680801)

plt.rcdefaults()
fig, ax = plt.subplots(figsize = (8, 6))

people = ('Tom', 'Dick','Harry', 'Slim', 'Jim')
y_pos = np.arange(len(people))
performance = 3 + 10*np.random.rand(len(people))
error = np.random.rand(len(people))

colors = sns.color_palette('hls', len(people))
ax.barh(y_pos, performance, xerr=error, align = 'center', color = colors)
ax.set_yticks(y_pos, labels = people)
ax.invert_yaxis() # labels read top-to-bottom
ax.set_xlabel('Performance')
ax.set_title('How fast do you want to go today?')
# Out:
# Text(0.5, 1.0, 'How fast do you want to go today?')
