# %% [markdown]
# <a href="https://colab.research.google.com/github/temple17/matplotlib-practice/blob/main/22_JoinStyle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
# !pip install matplotlib --upgrade

# %%
from matplotlib._enums import JoinStyle

# %%
JoinStyle.demo()
